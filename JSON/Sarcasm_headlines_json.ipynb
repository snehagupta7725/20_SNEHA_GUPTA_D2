# %%
import pandas as pd

# %%
df = pd.read_json(r"C:\Users\hp\Downloads\archive (1)\json\Sarcasm_Headlines_Dataset.json",encoding="utf-8",lines=True)

# %%
df
# Out:
#                                             article_link  \
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %%
df.index.name="id"

# %%
df
# Out:
#                                             article_link  \
# id
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# id
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26709 entries, 0 to 26708
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   article_link  26709 non-null  str
#  1   headline      26709 non-null  str
#  2   is_sarcastic  26709 non-null  int64
# dtypes: int64(1), str(2)
# memory usage: 626.1 KB

# %%
df.describe()
# Out:
#        is_sarcastic
# count  26709.000000
# mean       0.438953
# std        0.496269
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.shape
# Out:
# (26709, 3)

# %%
df.sample()
# Out:
#                                             article_link  \
# id
# 13053  https://www.huffingtonpost.com/entry/pistachio...
#
#                                                 headline  is_sarcastic
# id
# 13053  pistachio biscotti with kirsch-soaked dried ch...             0

# %%
df.isnull()
# Out:
#        article_link  headline  is_sarcastic
# id
# 0             False     False         False
# 1             False     False         False
# 2             False     False         False
# 3             False     False         False
# 4             False     False         False
# ...             ...       ...           ...
# 26704         False     False         False
# 26705         False     False         False
# 26706         False     False         False
# 26707         False     False         False
# 26708         False     False         False
#
# [26709 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# article_link    0
# headline        0
# is_sarcastic    0
# dtype: int64

# %%
df.drop(['headline'],axis=1)
# Out:
#                                             article_link  is_sarcastic
# id
# 0      https://www.huffingtonpost.com/entry/versace-b...             0
# 1      https://www.huffingtonpost.com/entry/roseanne-...             0
# 2      https://local.theonion.com/mom-starting-to-fea...             1
# 3      https://politics.theonion.com/boehner-just-wan...             1
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...             0
# ...                                                  ...           ...
# 26704  https://www.huffingtonpost.com/entry/american-...             0
# 26705  https://www.huffingtonpost.com/entry/americas-...             0
# 26706  https://www.huffingtonpost.com/entry/reparatio...             0
# 26707  https://www.huffingtonpost.com/entry/israeli-b...             0
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...             0
#
# [26709 rows x 2 columns]

# %%
df
# Out:
#                                             article_link  \
# id
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# id
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates()
# Out:
#                                             article_link  \
# id
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# id
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
df.dtypes
# Out:
# article_link      str
# headline          str
# is_sarcastic    int64
# dtype: object

# %%
df.rename(columns={'headline':'news_title'})
# Out:
#                                             article_link  \
# id
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                               news_title  is_sarcastic
# id
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...
