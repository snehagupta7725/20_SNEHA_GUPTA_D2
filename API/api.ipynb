# %%
import requests

# %%
url = "https://www.thesportsdb.com/api/v1/json/3/searchevents.php?e=Arsenal_vs_Chelsea&s=2016-2017"

response= requests.get(url)
json_data = response.json() 
response=response.json()
print(response)
# Out:
# {'event': [{'idEvent': '679698', 'idAPIfootball': None, 'strEvent': 'Arsenal vs Chelsea', 'strEventAlternate': 'Chelsea @ Arsenal', 'strFilename': 'FA Cup 2017-05-27 Arsenal vs Chelsea', 'strSport': 'Soccer', 'idLeague': '4482', 'strLeague': 'FA Cup', 'strLeagueBadge': 'https://r2.thesportsdb.com/images/media/league/badge/vk7isd1598802862.png', 'strSeason': '2016-2017', 'strDescriptionEN': '', 'strHomeTeam': 'Arsenal', 'strAwayTeam': 'Chelsea', 'intHomeScore': '2', 'intRound': '200', 'intAwayScore': '1', 'intSpectators': '89472', 'strOfficial': None, 'strTimestamp': None, 'dateEvent': '2017-05-27', 'dateEventLocal': '2017-05-27', 'strTime': '17:30:00', 'strTimeLocal': '', 'strGroup': None, 'idHomeTeam': '133604', 'strHomeTeamBadge': None, 'idAwayTeam': '133610', 'strAwayTeamBadge': None, 'intScore': None, 'intScoreVotes': None, 'strResult': '', 'idVenue': None, 'strVenue': None, 'strCountry': None, 'strCity': None, 'strPoster': None, 'strSquare': None, 'strFanart': None, 'strThumb': 
# ...

# %%
import json
import pandas as pd
df=pd.DataFrame(json_data['event'])

# %%
df
# Out:
#   idEvent idAPIfootball            strEvent  strEventAlternate  \
# 0  679698          None  Arsenal vs Chelsea  Chelsea @ Arsenal
# 1  508788          None  Arsenal vs Chelsea  Chelsea @ Arsenal
#
#                                          strFilename strSport idLeague  \
# 0               FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer     4482
# 1  English Premier League 2016-09-24 Arsenal vs C...   Soccer     4328
#
#                 strLeague                                     strLeagueBadge  \
# 0                  FA Cup  https://r2.thesportsdb.com/images/media/league...
# 1  English Premier League  https://r2.thesportsdb.com/images/media/league...
#
#    strSeason  ... strSquare strFanart strThumb strBanner strMap strTweet1  \
# 0  2016-2017  ...      None      None     None      None   None
# 1  2016-2017  ...      None      None     None      None   None       NaN
#
#                                       strVideo strStatus strPostponed  \
# ...

# %%
df.head()
# Out:
#   idEvent idAPIfootball            strEvent  strEventAlternate  \
# 0  679698          None  Arsenal vs Chelsea  Chelsea @ Arsenal
# 1  508788          None  Arsenal vs Chelsea  Chelsea @ Arsenal
#
#                                          strFilename strSport idLeague  \
# 0               FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer     4482
# 1  English Premier League 2016-09-24 Arsenal vs C...   Soccer     4328
#
#                 strLeague                                     strLeagueBadge  \
# 0                  FA Cup  https://r2.thesportsdb.com/images/media/league...
# 1  English Premier League  https://r2.thesportsdb.com/images/media/league...
#
#    strSeason  ... strSquare strFanart strThumb strBanner strMap strTweet1  \
# 0  2016-2017  ...      None      None     None      None   None
# 1  2016-2017  ...      None      None     None      None   None       NaN
#
#                                       strVideo strStatus strPostponed  \
# ...

# %%
df.shape
# Out:
# (2, 46)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   idEvent            2 non-null      str
#  1   idAPIfootball      0 non-null      object
#  2   strEvent           2 non-null      str
#  3   strEventAlternate  2 non-null      str
#  4   strFilename        2 non-null      str
#  5   strSport           2 non-null      str
#  6   idLeague           2 non-null      str
#  7   strLeague          2 non-null      str
#  8   strLeagueBadge     2 non-null      str
#  9   strSeason          2 non-null      str
#  10  strDescriptionEN   1 non-null      str
#  11  strHomeTeam        2 non-null      str
#  12  strAwayTeam        2 non-null      str
#  13  intHomeScore       2 non-null      str
#  14  intRound           2 non-null      str
#  15  intAwayScore       2 non-null      str
#  16  intSpectators      2 non-null      str
# ...

# %%
df.describe()
# Out:
#        idEvent idAPIfootball            strEvent  strEventAlternate  \
# count        2             0                   2                  2
# unique       2             0                   1                  1
# top     679698           NaN  Arsenal vs Chelsea  Chelsea @ Arsenal
# freq         1           NaN                   2                  2
#
#                                  strFilename strSport idLeague strLeague  \
# count                                      2        2        2         2
# unique                                     2        1        2         2
# top     FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer     4482    FA Cup
# freq                                       1        2        1         1
#
#                                            strLeagueBadge  strSeason  ...  \
# count                                                   2          2  ...
# unique                                                  2          1  ...
# ...

# %%
df.isnull()
# Out:
#    idEvent  idAPIfootball  strEvent  strEventAlternate  strFilename  strSport  \
# 0    False           True     False              False        False     False
# 1    False           True     False              False        False     False
#
#    idLeague  strLeague  strLeagueBadge  strSeason  ...  strSquare  strFanart  \
# 0     False      False           False      False  ...       True       True
# 1     False      False           False      False  ...       True       True
#
#    strThumb  strBanner  strMap  strTweet1  strVideo  strStatus  strPostponed  \
# 0      True       True    True      False     False       True         False
# 1      True       True    True       True      True       True         False
#
#    strLocked
# 0      False
# 1      False
#
# [2 rows x 46 columns]

# %%
df.isnull().sum()
# Out:
# idEvent              0
# idAPIfootball        2
# strEvent             0
# strEventAlternate    0
# strFilename          0
# strSport             0
# idLeague             0
# strLeague            0
# strLeagueBadge       0
# strSeason            0
# strDescriptionEN     1
# strHomeTeam          0
# strAwayTeam          0
# intHomeScore         0
# intRound             0
# intAwayScore         0
# intSpectators        0
# strOfficial          2
# strTimestamp         2
# dateEvent            0
# dateEventLocal       1
# strTime              0
# strTimeLocal         1
# strGroup             2
# idHomeTeam           0
# strHomeTeamBadge     2
# idAwayTeam           0
# strAwayTeamBadge     2
# intScore             2
# intScoreVotes        2
# strResult            1
# idVenue              2
# strVenue             2
# strCountry           2
# strCity              2
# strPoster            2
# strSquare            2
# strFanart            2
# strThumb             2
# strBanner            2
# ...

# %%
df.fillna("NAN")
# Out:
#   idEvent idAPIfootball            strEvent  strEventAlternate  \
# 0  679698           NAN  Arsenal vs Chelsea  Chelsea @ Arsenal
# 1  508788           NAN  Arsenal vs Chelsea  Chelsea @ Arsenal
#
#                                          strFilename strSport idLeague  \
# 0               FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer     4482
# 1  English Premier League 2016-09-24 Arsenal vs C...   Soccer     4328
#
#                 strLeague                                     strLeagueBadge  \
# 0                  FA Cup  https://r2.thesportsdb.com/images/media/league...
# 1  English Premier League  https://r2.thesportsdb.com/images/media/league...
#
#    strSeason  ... strSquare strFanart strThumb strBanner strMap strTweet1  \
# 0  2016-2017  ...       NAN       NAN      NAN       NAN    NAN
# 1  2016-2017  ...       NAN       NAN      NAN       NAN    NAN       NAN
#
#                                       strVideo strStatus strPostponed  \
# ...

# %%
df.isna().sum()
# Out:
# idEvent              0
# idAPIfootball        2
# strEvent             0
# strEventAlternate    0
# strFilename          0
# strSport             0
# idLeague             0
# strLeague            0
# strLeagueBadge       0
# strSeason            0
# strDescriptionEN     1
# strHomeTeam          0
# strAwayTeam          0
# intHomeScore         0
# intRound             0
# intAwayScore         0
# intSpectators        0
# strOfficial          2
# strTimestamp         2
# dateEvent            0
# dateEventLocal       1
# strTime              0
# strTimeLocal         1
# strGroup             2
# idHomeTeam           0
# strHomeTeamBadge     2
# idAwayTeam           0
# strAwayTeamBadge     2
# intScore             2
# intScoreVotes        2
# strResult            1
# idVenue              2
# strVenue             2
# strCountry           2
# strCity              2
# strPoster            2
# strSquare            2
# strFanart            2
# strThumb             2
# strBanner            2
# ...

# %%
df.columns
# Out:
# Index(['idEvent', 'idAPIfootball', 'strEvent', 'strEventAlternate',
#        'strFilename', 'strSport', 'idLeague', 'strLeague', 'strLeagueBadge',
#        'strSeason', 'strDescriptionEN', 'strHomeTeam', 'strAwayTeam',
#        'intHomeScore', 'intRound', 'intAwayScore', 'intSpectators',
#        'strOfficial', 'strTimestamp', 'dateEvent', 'dateEventLocal', 'strTime',
#        'strTimeLocal', 'strGroup', 'idHomeTeam', 'strHomeTeamBadge',
#        'idAwayTeam', 'strAwayTeamBadge', 'intScore', 'intScoreVotes',
#        'strResult', 'idVenue', 'strVenue', 'strCountry', 'strCity',
#        'strPoster', 'strSquare', 'strFanart', 'strThumb', 'strBanner',
#        'strMap', 'strTweet1', 'strVideo', 'strStatus', 'strPostponed',
#        'strLocked'],
#       dtype='str')

# %%
df.index_col='idEvent'

# %%
df
# Out:
#         idAPIfootball            strEvent  strEventAlternate  \
# idEvent
# 679698           None  Arsenal vs Chelsea  Chelsea @ Arsenal
# 508788           None  Arsenal vs Chelsea  Chelsea @ Arsenal
#
#                                                strFilename strSport idLeague  \
# idEvent
# 679698                FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer     4482
# 508788   English Premier League 2016-09-24 Arsenal vs C...   Soccer     4328
#
#                       strLeague  \
# idEvent
# 679698                   FA Cup
# 508788   English Premier League
#
#                                             strLeagueBadge  strSeason  \
# idEvent
# 679698   https://r2.thesportsdb.com/images/media/league...  2016-2017
# 508788   https://r2.thesportsdb.com/images/media/league...  2016-2017
#
#         strDescriptionEN  ... strSquare strFanart strThumb strBanner strMap  \
# idEvent                   ...
# 679698                    ...      None      None     None      None   None
# ...

# %%
df['idAPIfootball'].dtype
# Out:
# dtype('O')

# %%
df['strFilename']
# Out:
# idEvent
# 679698                 FA Cup 2017-05-27 Arsenal vs Chelsea
# 508788    English Premier League 2016-09-24 Arsenal vs C...
# Name: strFilename, dtype: str

# %%
df.rename(columns={'idLeague':'League'},inplace=True)

# %%
df
# Out:
#         idAPIfootball            strEvent  strEventAlternate  \
# idEvent
# 679698           None  Arsenal vs Chelsea  Chelsea @ Arsenal
# 508788           None  Arsenal vs Chelsea  Chelsea @ Arsenal
#
#                                                strFilename strSport League  \
# idEvent
# 679698                FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer   4482
# 508788   English Premier League 2016-09-24 Arsenal vs C...   Soccer   4328
#
#                       strLeague  \
# idEvent
# 679698                   FA Cup
# 508788   English Premier League
#
#                                             strLeagueBadge  strSeason  \
# idEvent
# 679698   https://r2.thesportsdb.com/images/media/league...  2016-2017
# 508788   https://r2.thesportsdb.com/images/media/league...  2016-2017
#
#         strDescriptionEN  ... strSquare strFanart strThumb strBanner strMap  \
# idEvent                   ...
# 679698                    ...      None      None     None      None   None
# ...

# %%
df.iloc[0:1]# first row
# Out:
#         idAPIfootball            strEvent  strEventAlternate  \
# idEvent
# 679698           None  Arsenal vs Chelsea  Chelsea @ Arsenal
#
#                                   strFilename strSport League strLeague  \
# idEvent
# 679698   FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer   4482    FA Cup
#
#                                             strLeagueBadge  strSeason  \
# idEvent
# 679698   https://r2.thesportsdb.com/images/media/league...  2016-2017
#
#         strDescriptionEN  ... strSquare strFanart strThumb strBanner strMap  \
# idEvent                   ...
# 679698                    ...      None      None     None      None   None
#
#         strTweet1                                     strVideo strStatus  \
# idEvent
# 679698             https://www.youtube.com/watch?v=OOkzIJ2Ge2M      None
#
#         strPostponed strLocked
# idEvent
# 679698            no  unlocked
#
# [1 rows x 45 columns]

# %%
df[df['strHomeTeam']=='Arsenal']
# Out:
#         idAPIfootball            strEvent  strEventAlternate  \
# idEvent
# 679698           None  Arsenal vs Chelsea  Chelsea @ Arsenal
# 508788           None  Arsenal vs Chelsea  Chelsea @ Arsenal
#
#                                                strFilename strSport League  \
# idEvent
# 679698                FA Cup 2017-05-27 Arsenal vs Chelsea   Soccer   4482
# 508788   English Premier League 2016-09-24 Arsenal vs C...   Soccer   4328
#
#                       strLeague  \
# idEvent
# 679698                   FA Cup
# 508788   English Premier League
#
#                                             strLeagueBadge  strSeason  \
# idEvent
# 679698   https://r2.thesportsdb.com/images/media/league...  2016-2017
# 508788   https://r2.thesportsdb.com/images/media/league...  2016-2017
#
#         strDescriptionEN  ... strSquare strFanart strThumb strBanner strMap  \
# idEvent                   ...
# 679698                    ...      None      None     None      None   None
# ...

# %%
df.dtypes
# Out:
# idAPIfootball        object
# strEvent                str
# strEventAlternate       str
# strFilename             str
# strSport                str
# League                  str
# strLeague               str
# strLeagueBadge          str
# strSeason               str
# strDescriptionEN        str
# strHomeTeam             str
# strAwayTeam             str
# intHomeScore            str
# intRound                str
# intAwayScore            str
# intSpectators           str
# strOfficial          object
# strTimestamp         object
# dateEvent               str
# dateEventLocal          str
# strTime                 str
# strTimeLocal            str
# strGroup             object
# idHomeTeam              str
# strHomeTeamBadge     object
# idAwayTeam              str
# strAwayTeamBadge     object
# intScore             object
# intScoreVotes        object
# strResult               str
# idVenue              object
# strVenue             object
# strCountry           object
# ...
